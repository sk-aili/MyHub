# %% [markdown]
# <a href="https://colab.research.google.com/github/sk-aili/MyHub/blob/main/Hands_On_Approach_to_Causal_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Business Problem: The Sprinkler Problem
#
# How effective is our sprinkler is making the grass wet?
# Treatment: Sprinkler - 1 (Turned On) or 0 (Turned Off)
# Outcome: Wet grass - 1 (Wet) or 0 (Dry)
#
# Other Variables:
# Rain - 1 (Rain) or 0 (Didn't rain)
# Cloudy - 1 (Cloudy) or 0 (wasn't Cloudy)

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# Install Requirements

# %%
! pip install numpy==1.24.2

# %%
! pip install bnlearn --quiet

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import bnlearn as bn

# %% [markdown]
# ## Dataset

# %%
df = bn.import_example("sprinkler")
df.head()
# Out:
#    Cloudy  Sprinkler  Rain  Wet_Grass
# 0       0          0     0          0
# 1       1          0     1          1
# 2       0          1     0          1
# 3       1          1     1          1
# 4       1          1     1          1

# %% [markdown]
# ## Step 0: How different are our treatment (Sprinkler == 1) and Control (Sprinkler == 0) Groups? (in regards to Cloudy)

# %%
df.groupby(['Sprinkler', 'Cloudy']).agg({'Wet_Grass': 'count'})
# Out:
#                   Wet_Grass
# Sprinkler Cloudy
# 0         0             225
#           1             466
# 1         0             263
#           1              46

# %% [markdown]
# We have a lot less cloudy days (46) in our Treatment group as opposed to the control group (466). We need to match them. How to do it? [Using Propensity score]
